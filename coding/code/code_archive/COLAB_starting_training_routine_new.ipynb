# %%
# to run in console as to not have google colab deconnect runtime

function ClickConnect(){
console.log("Working"); 
document.querySelector("colab-toolbar-button").click() 
}setInterval(ClickConnect,60000)

# %%
# installing required packages 
# !pip install torchviz
# Out:
# Collecting torchviz
#   Downloading https://files.pythonhosted.org/packages/8f/8e/a9630c7786b846d08b47714dd363a051f5e37b4ea0e534460d8cdfc1644b/torchviz-0.0.1.tar.gz (41kB)
#      |████████████████████████████████| 51kB 8.4MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchviz) (1.4.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from torchviz) (0.10.1)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.1-cp36-none-any.whl size=3523 sha256=d0294934a32e6d951111329b3bf14d24d08483679fa2f3781972e473ff863ec8
#   Stored in directory: /root/.cache/pip/wheels/2a/c2/c5/b8b4d0f7992c735f6db5bfa3c5f354cf36502037ca2b585667
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Setting relative path to Working directory
import os
os.chdir("/content/drive/My Drive/Masterstudium/Inhalte/4th Semester/NLP/nlp-project/coding/code")
# !pwd
# Out:
# /content/drive/My Drive/Masterstudium/Inhalte/4th Semester/NLP/nlp-project/coding/code

# %%
# Training the model
# !python "M3_2_training_model.py"
# Out:
# Epoch [9/90], Step [3000/4837], Loss: 0.8183
# Epoch [9/90], Step [4000/4837], Loss: 0.9870
# Test Accuracy on Validation: 61.186938857717664 %
# F1-score Macro on Validation: 0.4958601436675085
# Precision of Hate on Validation: 0.11728931364031277
# Recall of Hate on Validation: 0.2912621359223301
# F1-score of Hate on Validation: 0.1672344379064726
# save model to exchange_base/Model_Results/FINAL_TRAINING_1D_gs26_90epochs/26_CNN_experiment_1D_optimizer_Adam_lr_01_epochs_90_batchsize_16_samplerTclassweightsF_False_scheduler_True/Model_epoch_8.pt
# Epoch [10/90], Step [1000/4837], Loss: 1.2135
# Epoch [10/90], Step [2000/4837], Loss: 0.9010
# Epoch [10/90], Step [3000/4837], Loss: 0.8064
# Epoch [10/90], Step [4000/4837], Loss: 1.1350
# Test Accuracy on Validation: 64.40171179155432 %
# F1-score Macro on Validation: 0.5081406319805534
# Precision of Hate on Validation: 0.14168937329700274
# Recall of Hate on Validation: 0.2243797195253506
# F1-score of Hate on Validation: 0.1736951983298539
# save model to exchange_base/Model_Results/FINAL_TRAINING_1D_gs26_90epochs/26_CNN_experiment_1D_optimizer_Adam_lr_01_epochs_90_batchsize_16_samplerTclassweightsF_False_scheduler_True/Model_epoch_9.pt
# Epoch [11/90], Step [1000/4837], Loss: 0.7091
# Epoch [11/90], Step [2000/4837], Loss: 1.0630
# Epoch [11/90], Step [3000/4837], Loss: 1.1495
# Epoch [11/90], Step [4000/4837], Loss: 1.1632
# Test Accuracy on Validation: 67.1709181908702 %
# F1-score Macro on Validation: 0.5177033823407476
# Precision of Hate on Validation: 0.21279373368146215
# Recall of Hate on Validation: 0.17583603020496225
# F1-score of Hate on Validation: 0.19255759007678677
# save model to exchange_base/Model_Results/FINAL_TRAINING_1D_gs26_90epochs/26_CNN_experiment_1D_optimizer_Adam_lr_01_epochs_90_batchsize_16_samplerTclassweightsF_False_scheduler_True/Model_epoch_10.pt
# Epoch [12/90], Step [1000/4837], Loss: 0.6928
# Epoch [12/90], Step [2000/4837], Loss: 0.8534
# Epoch [12/90], Step [3000/4837], Loss: 0.6598
# Epoch [12/90], Step [4000/4837], Loss: 1.1420
# Test Accuracy on Validation: 65.08569081548322 %
# F1-score Macro on Validation: 0.5140230205432376
# Precision of Hate on Validation: 0.18163471241170534
# Recall of Hate on Validation: 0.1941747572815534
# F1-score of Hate on Validation: 0.18769551616266944
# save model to exchange_base/Model_Results/FINAL_TRAINING_1D_gs26_90epochs/26_CNN_experiment_1D_optimizer_Adam_lr_01_epochs_90_batchsize_16_samplerTclassweightsF_False_scheduler_True/Model_epoch_11.pt
# Epoch [13/90], Step [1000/4837], Loss: 1.0553
# Epoch [13/90], Step [2000/4837], Loss: 0.8253
# Epoch [13/90], Step [3000/4837], Loss: 1.2876
# Epoch [13/90], Step [4000/4837], Loss: 0.9810
# Test Accuracy on Validation: 66.3932273743879 %
# F1-score Macro on Validation: 0.523485345065481
# Precision of Hate on Validation: 0.18762088974854932
# Recall of Hate on Validation: 0.209277238403452
# F1-score of Hate on Validation: 0.19785823559408464
# save model to exchange_base/Model_Results/FINAL_TRAINING_1D_gs26_90epochs/26_CNN_experiment_1D_optimizer_Adam_lr_01_epochs_90_batchsize_16_samplerTclassweightsF_False_scheduler_True/Model_epoch_12.pt
# Epoch [14/90], Step [1000/4837], Loss: 0.9472
# Epoch [14/90], Step [2000/4837], Loss: 0.6592
# Epoch [14/90], Step [3000/4837], Loss: 0.7597
# Epoch [14/90], Step [4000/4837], Loss: 0.8546
# Test Accuracy on Validation: 68.26912449475935 %
# F1-score Macro on Validation: 0.48582532941050766
# Precision of Hate on Validation: 0.1935483870967742
# Recall of Hate on Validation: 0.038834951456310676
# F1-score of Hate on Validation: 0.0646900269541779
# save model to exchange_base/Model_Results/FINAL_TRAINING_1D_gs26_90epochs/26_CNN_experiment_1D_optimizer_Adam_lr_01_epochs_90_batchsize_16_samplerTclassweightsF_False_scheduler_True/Model_epoch_13.pt
# Epoch [15/90], Step [1000/4837], Loss: 1.1701
# Epoch [15/90], Step [2000/4837], Loss: 0.8390
# Epoch [15/90], Step [3000/4837], Loss: 0.8822
# Epoch [15/90], Step [4000/4837], Loss: 0.6459
# Test Accuracy on Validation: 62.95929337730623 %
# F1-score Macro on Validation: 0.505404913411119
# Precision of Hate on Validation: 0.12846481876332622
# Recall of Hate on Validation: 0.2599784250269687
# F1-score of Hate on Validation: 0.17195861576881913
# save model to exchange_base/Model_Results/FINAL_TRAINING_1D_gs26_90epochs/26_CNN_experiment_1D_optimizer_Adam_lr_01_epochs_90_batchsize_16_samplerTclassweightsF_False_scheduler_True/Model_epoch_14.pt
# Epoch [16/90], Step [1000/4837], Loss: 1.0437
# Epoch [16/90], Step [2000/4837], Loss: 0.8232
# Epoch [16/90], Step [3000/4837], Loss: 1.1096
# Epoch [16/90], Step [4000/4837], Loss: 1.0703
# Test Accuracy on Validation: 67.17022369736732 %
# F1-score Macro on Validation: 0.5303662794002172
# Precision of Hate on Validation: 0.18950437317784258
# Recall of Hate on Validation: 0.21035598705501618
# F1-score of Hate on Validation: 0.19938650306748468
# save model to exchange_base/Model_Results/FINAL_TRAINING_1D_gs26_90epochs/26_CNN_experiment_1D_optimizer_Adam_lr_01_epochs_90_batchsize_16_samplerTclassweightsF_False_scheduler_True/Model_epoch_15.pt
# Epoch [17/90], Step [1000/4837], Loss: 0.5592
# Epoch [17/90], Step [2000/4837], Loss: 0.8660
# Epoch [17/90], Step [3000/4837], Loss: 0.6039
# Epoch [17/90], Step [4000/4837], Loss: 1.0700
# Test Accuracy on Validation: 66.95414802259174 %
# F1-score Macro on Validation: 0.49456292006649666
# Precision of Hate on Validation: 0.1180327868852459
# Recall of Hate on Validation: 0.07766990291262135
# F1-score of Hate on Validation: 0.0936890045543266
# save model to exchange_base/Model_Results/FINAL_TRAINING_1D_gs26_90epochs/26_CNN_experiment_1D_optimizer_Adam_lr_01_epochs_90_batchsize_16_samplerTclassweightsF_False_scheduler_True/Model_epoch_16.pt
# Epoch [18/90], Step [1000/4837], Loss: 0.6807
# Epoch [18/90], Step [2000/4837], Loss: 0.6630
# Epoch [18/90], Step [3000/4837], Loss: 1.0211
