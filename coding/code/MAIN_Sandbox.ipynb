# %%
import pandas as pd
from M1_5_dictionary_approach import apply_dict
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-18ec5346bc48> in <module>()
#       1 import pandas as pd
# ----> 2 from M1_5_dictionary_approach import apply_dict
#
# ModuleNotFoundError: No module named 'M1_5_dictionary_approach'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive
drive.mount('/content/drive')
root_path = "/content/drive/My Drive/Masterstudium/Inhalte/4th Semester/NLP/nlp-project/coding"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ln -s "/drive/Masterstudium/Inhalte/4th Semester/NLP/nlp-project/coding/code" "/content/code"
# Out:
# ln: failed to create symbolic link '/content/code': File exists

# %%
data = pd.read_csv("exchange_base/data.csv")

# %%
data_sub = data.iloc[:40]

# %%
dictionary = pd.read_csv('exchange_base/full_dictionary.csv')
hatebase_dic = dictionary

# %%
HateFrequency, HateIntensity, dataset_with_hatebasecount = apply_dict(data_sub, dictionary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-8bc0cfbdc28f> in <module>
# ----> 1 HateFrequency, HateIntensity, dataset_with_hatebasecount = apply_dict(data_sub, dictionary)
#
# ~/Google Drive/Masterstudium/Inhalte/4th Semester/NLP/nlp-project/coding/code/M1_5_dictionary_approach.py in apply_dict(data, dictionary)
#      99     #pandarallel.initialize()
#     100     #data = data.parallel_apply(hatesearch, axis = 1)
# --> 101     data = data.apply(hatesearch, axis = 1)
#     102
#     103     # Building a tensor out of the additional columns
#
# /anaconda3/envs/nlp-project/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ...
